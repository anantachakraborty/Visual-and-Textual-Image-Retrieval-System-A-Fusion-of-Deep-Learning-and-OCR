# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #ffeacc; font-size:130%; text-align:left">
# Import Libraries and Initialize Variables

# %%
import os
import h5py
import numpy as np
import pytesseract
from PIL import Image
from VGG_feature_extractor import VGGNet
from sklearn.feature_extraction.text import TfidfVectorizer
import pickle

# Define the path to your images directory
images_path = "all_images/"
img_list = [os.path.join(images_path, f) for f in os.listdir(images_path)]

# Initialize the VGGNet model for feature extraction
print("Start feature extraction")
model = VGGNet()

# Lists to store features, image names, and extracted texts
feats = []
names = []
texts = []
# Out:
# Start feature extraction
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #ffeacc; font-size:130%; text-align:left">
# Function to Extract Text Using Tesseract

# %%
# Function to extract text from an image using Tesseract
def extract_text(image_path):
    try:
        image = Image.open(image_path)
        text = pytesseract.image_to_string(image)
        return text
    except Exception as e:
        print(f"Error processing {image_path}: {e}")
        return ""

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #ffeacc; font-size:130%; text-align:left">
# Extract Features from Images

# %%
# Iterate through all images to extract VGG-16 features and text features
for im in os.listdir(images_path):
    print("Extracting features from image - ", im)
    image_path = os.path.join(images_path, im)
    
    # Extract VGG-16 features
    X = model.extract_feat(image_path)
    feats.append(X)
    names.append(im)
    
    # Extract text from the image
    text = extract_text(image_path)
    texts.append(text)

# Convert lists to numpy arrays
feats = np.array(feats)
# Out:
# Extracting features from image -  0.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# Extracting features from image -  0000001.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# Extracting features from image -  0000002.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# Extracting features from image -  0000003.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# Extracting features from image -  0000004.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# Extracting features from image -  0000005.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# Extracting features from image -  0000006.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# Extracting features from image -  0000007.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# Extracting features from image -  0000008.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# Extracting features from image -  0000009.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# Extracting features from image -  0000010.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# Extracting features from image -  0000011.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# Extracting features from image -  0000012.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# Extracting features from image -  0000013.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# Extracting features from image -  0000014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# Extracting features from image -  0000015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# Extracting features from image -  0000061.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# Extracting features from image -  0000062.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# Extracting features from image -  0000063.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# Extracting features from image -  0000064.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# Extracting features from image -  0000065.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# Extracting features from image -  0000066.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# Extracting features from image -  0000067.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# Extracting features from image -  0000068.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# Extracting features from image -  0000069.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# Extracting features from image -  0000070.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# Extracting features from image -  0000071.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# Extracting features from image -  0000072.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# Extracting features from image -  0000073.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# Extracting features from image -  0000074.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# Extracting features from image -  0000075.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# Extracting features from image -  0000076.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# Extracting features from image -  0000077.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# Extracting features from image -  0000078.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step
# Extracting features from image -  0000079.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# Extracting features from image -  0000080.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# Extracting features from image -  0000081.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# Extracting features from image -  0000082.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# Extracting features from image -  0000083.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# Extracting features from image -  0000084.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# Extracting features from image -  0000085.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# Extracting features from image -  0000086.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# Extracting features from image -  0000087.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# Extracting features from image -  0000088.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# Extracting features from image -  0000089.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# Extracting features from image -  0000090.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# Extracting features from image -  0000091.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# Extracting features from image -  0000092.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# Extracting features from image -  0000093.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# Extracting features from image -  0000094.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# Extracting features from image -  0000095.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# Extracting features from image -  0000096.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# Extracting features from image -  0000097.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# Extracting features from image -  0000098.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# Extracting features from image -  0000099.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# Extracting features from image -  0000100.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# Extracting features from image -  0000101.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# Extracting features from image -  0000102.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# Extracting features from image -  0000103.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# Extracting features from image -  0000104.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# Extracting features from image -  0000105.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# Extracting features from image -  0000106.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# Extracting features from image -  0000107.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# Extracting features from image -  0000108.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# Extracting features from image -  0000109.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# Extracting features from image -  0000110.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# Extracting features from image -  0000111.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step
# Extracting features from image -  0000112.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# Extracting features from image -  0000113.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# Extracting features from image -  0000114.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# Extracting features from image -  0000115.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# Extracting features from image -  0000116.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step
# Extracting features from image -  0000117.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step
# Extracting features from image -  0000118.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# Extracting features from image -  0000119.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# Extracting features from image -  0000120.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step
# Extracting features from image -  0000121.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# Extracting features from image -  0000122.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step
# Extracting features from image -  0000123.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# Extracting features from image -  0000124.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step
# Extracting features from image -  0000125.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# Extracting features from image -  0000126.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# Extracting features from image -  0000127.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# Extracting features from image -  0000128.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# Extracting features from image -  0000129.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# Extracting features from image -  0000130.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step
# Extracting features from image -  0000131.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# Extracting features from image -  0000132.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# Extracting features from image -  0000133.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step
# Extracting features from image -  0000134.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# Extracting features from image -  0000135.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# Extracting features from image -  0000136.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# Extracting features from image -  0000137.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# Extracting features from image -  0000138.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step
# Extracting features from image -  0000139.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step
# Extracting features from image -  0000140.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step
# Extracting features from image -  0000141.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step
# Extracting features from image -  0000142.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# Extracting features from image -  0000143.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step
# Extracting features from image -  0000144.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# Extracting features from image -  0000145.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# Extracting features from image -  0000146.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step
# Extracting features from image -  0000147.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step
# Extracting features from image -  0000148.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# Extracting features from image -  0000149.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# Extracting features from image -  0000150.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# Extracting features from image -  0001.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# Extracting features from image -  0002.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# Extracting features from image -  0003.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# Extracting features from image -  0005.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# Extracting features from image -  0006.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# Extracting features from image -  0007.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step
# Extracting features from image -  0008.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# Extracting features from image -  0011.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# Extracting features from image -  0012.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step
# Extracting features from image -  0013.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# Extracting features from image -  0014.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# Extracting features from image -  0015.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# Extracting features from image -  0016.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# Extracting features from image -  0017.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# Extracting features from image -  0018.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step
# Extracting features from image -  0019.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# Extracting features from image -  0060.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# Extracting features from image -  0061.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# Extracting features from image -  0062.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step
# Extracting features from image -  0063.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# Extracting features from image -  0064.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# Extracting features from image -  0065.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# Extracting features from image -  0067.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# Extracting features from image -  0068.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step
# Extracting features from image -  0069.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# Extracting features from image -  0070.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# Extracting features from image -  0071.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step
# Extracting features from image -  0072.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# Extracting features from image -  0073.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# Extracting features from image -  0074.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# Extracting features from image -  0075.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# Extracting features from image -  0076.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# Extracting features from image -  0077.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# Extracting features from image -  0078.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# Extracting features from image -  0079.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# Extracting features from image -  0080.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# Extracting features from image -  0081.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# Extracting features from image -  0082.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# Extracting features from image -  0084.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# Extracting features from image -  0085.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step
# Extracting features from image -  0087.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# Extracting features from image -  0088.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# Extracting features from image -  0089.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step
# Extracting features from image -  0090.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# Extracting features from image -  0091.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# Extracting features from image -  0092.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# Extracting features from image -  0094.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# Extracting features from image -  0095.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# Extracting features from image -  0097.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# Extracting features from image -  0098.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# Extracting features from image -  0099.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# Extracting features from image -  0100.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# Extracting features from image -  0101.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# Extracting features from image -  0102.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# Extracting features from image -  0103.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# Extracting features from image -  0104.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# Extracting features from image -  0105.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# Extracting features from image -  0106.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step
# Extracting features from image -  0107.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# Extracting features from image -  0108.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# Extracting features from image -  0109.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step
# Extracting features from image -  0110.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# Extracting features from image -  0111.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# Extracting features from image -  0112.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step
# Extracting features from image -  0113.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# Extracting features from image -  0114.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# Extracting features from image -  0115.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# Extracting features from image -  0116.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step
# Extracting features from image -  0117.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# Extracting features from image -  0118.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# Extracting features from image -  0119.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# Extracting features from image -  0120.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# Extracting features from image -  0121.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# Extracting features from image -  0122.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# Extracting features from image -  0125.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# Extracting features from image -  0126.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# Extracting features from image -  0127.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# Extracting features from image -  0128.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# Extracting features from image -  0129.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# Extracting features from image -  0130.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# Extracting features from image -  0131.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# Extracting features from image -  0132.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# Extracting features from image -  0133.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# Extracting features from image -  0135.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# Extracting features from image -  0136.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# Extracting features from image -  0137.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# Extracting features from image -  0138.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# Extracting features from image -  0139.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# Extracting features from image -  0141.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step
# Extracting features from image -  0142.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# Extracting features from image -  0143.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# Extracting features from image -  0144.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step
# Extracting features from image -  0145.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# Extracting features from image -  0146.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# Extracting features from image -  0147.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step
# Extracting features from image -  0148.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# Extracting features from image -  0149.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# Extracting features from image -  0150.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step
# Extracting features from image -  0151.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# Extracting features from image -  0153.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step
# Extracting features from image -  0154.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step
# Extracting features from image -  0155.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# Extracting features from image -  0156.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# Extracting features from image -  0157.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# Extracting features from image -  0158.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# Extracting features from image -  0159.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step
# Extracting features from image -  0160.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step
# Extracting features from image -  0161.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# Extracting features from image -  0162.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# Extracting features from image -  0163.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# Extracting features from image -  0164.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step
# Extracting features from image -  0165.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# Extracting features from image -  0166.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# Extracting features from image -  0167.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# Extracting features from image -  0168.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# Extracting features from image -  0169.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# Extracting features from image -  0170.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step
# Extracting features from image -  0171.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# Extracting features from image -  0172.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# Extracting features from image -  0173.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# Extracting features from image -  0175.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# Extracting features from image -  0176.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# Extracting features from image -  0177.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# Extracting features from image -  0178.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# Extracting features from image -  0179.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# Extracting features from image -  0180.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step
# Extracting features from image -  0181.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# Extracting features from image -  0182.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# Extracting features from image -  0183.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# Extracting features from image -  0184.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# Extracting features from image -  0185.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step
# Extracting features from image -  0186.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# Extracting features from image -  0187.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# Extracting features from image -  0188.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# Extracting features from image -  0189.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step
# Extracting features from image -  0190.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# Extracting features from image -  0191.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# Extracting features from image -  0192.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# Extracting features from image -  0193.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# Extracting features from image -  0194.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# Extracting features from image -  0195.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step
# Extracting features from image -  0196.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# Extracting features from image -  0197.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# Extracting features from image -  0198.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# Extracting features from image -  0199.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step
# Extracting features from image -  0200.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# Extracting features from image -  0201.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step
# Extracting features from image -  0202.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# Extracting features from image -  0203.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# Extracting features from image -  0204.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# Extracting features from image -  0206.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# Extracting features from image -  0207.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# Extracting features from image -  0209.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# Extracting features from image -  0210.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step
# Extracting features from image -  1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# Extracting features from image -  12753.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# Extracting features from image -  12756.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step
# Extracting features from image -  12763.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# Extracting features from image -  12764.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# Extracting features from image -  12765.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# Extracting features from image -  12774.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# Extracting features from image -  12778.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# Extracting features from image -  12781.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# Extracting features from image -  12784.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# Extracting features from image -  12785.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# Extracting features from image -  12791.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step
# Extracting features from image -  12796.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step
# Extracting features from image -  12797.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# Extracting features from image -  12800.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# Extracting features from image -  12804.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# Extracting features from image -  12809.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# Extracting features from image -  12812.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# Extracting features from image -  12813.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step
# Extracting features from image -  12816.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# Extracting features from image -  12824.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# Extracting features from image -  12825.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step
# Extracting features from image -  12828.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# Extracting features from image -  12830.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# Extracting features from image -  12831.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step
# Extracting features from image -  12832.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# Extracting features from image -  12833.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# Extracting features from image -  12834.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# Extracting features from image -  12835.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# Extracting features from image -  12836.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# Extracting features from image -  12838.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step
# Extracting features from image -  12841.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# Extracting features from image -  12842.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# Extracting features from image -  12844.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# Extracting features from image -  12847.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
# Extracting features from image -  12850.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# Extracting features from image -  12851.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step
# Extracting features from image -  12853.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# Extracting features from image -  12854.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step
# Extracting features from image -  12856.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# Extracting features from image -  12859.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# Extracting features from image -  12860.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# Extracting features from image -  12866.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# Extracting features from image -  12867.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# Extracting features from image -  12869.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# Extracting features from image -  12879.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# Extracting features from image -  12891.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# Extracting features from image -  12959.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# Extracting features from image -  12960.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# Extracting features from image -  12961.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# Extracting features from image -  12962.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# Extracting features from image -  12964.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# Extracting features from image -  12966.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# Extracting features from image -  12969.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step
# Extracting features from image -  12970.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# Extracting features from image -  12971.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# Extracting features from image -  12972.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step
# Extracting features from image -  12975.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step
# Extracting features from image -  12977.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# Extracting features from image -  12978.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step
# Extracting features from image -  12979.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# Extracting features from image -  12980.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# Extracting features from image -  12984.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# Extracting features from image -  12985.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# Extracting features from image -  12989.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# Extracting features from image -  12997.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# Extracting features from image -  13001.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step
# Extracting features from image -  13004.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# Extracting features from image -  13007.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# Extracting features from image -  13012.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step
# Extracting features from image -  13014.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# Extracting features from image -  13015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# Extracting features from image -  13016.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# Extracting features from image -  13017.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step
# Extracting features from image -  13018.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# Extracting features from image -  13022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# Extracting features from image -  13028.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step
# Extracting features from image -  13029.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# Extracting features from image -  13031.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step
# Extracting features from image -  13034.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step
# Extracting features from image -  13036.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# Extracting features from image -  13037.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# Extracting features from image -  13039.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# Extracting features from image -  13042.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# Extracting features from image -  13047.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# Extracting features from image -  13055.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step
# Extracting features from image -  13060.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# Extracting features from image -  13178.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step
# Extracting features from image -  13179.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# Extracting features from image -  13192.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# Extracting features from image -  13193.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# Extracting features from image -  13199.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step
# Extracting features from image -  13202.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step
# Extracting features from image -  13204.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# Extracting features from image -  13208.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# Extracting features from image -  13214.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step
# Extracting features from image -  13224.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step
# Extracting features from image -  13227.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# Extracting features from image -  13230.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step
# Extracting features from image -  13237.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# Extracting features from image -  13239.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# Extracting features from image -  13243.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# Extracting features from image -  13246.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# Extracting features from image -  13252.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# Extracting features from image -  13255.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# Extracting features from image -  13256.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# Extracting features from image -  13260.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# Extracting features from image -  13261.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# Extracting features from image -  13262.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step
# Extracting features from image -  13269.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# Extracting features from image -  13271.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# Extracting features from image -  13275.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# Extracting features from image -  13282.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# Extracting features from image -  13283.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# Extracting features from image -  13290.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step
# Extracting features from image -  13291.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# Extracting features from image -  13292.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# Extracting features from image -  13295.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# Extracting features from image -  13296.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step
# Extracting features from image -  13297.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# Extracting features from image -  13299.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# Extracting features from image -  13302.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# Extracting features from image -  13303.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# Extracting features from image -  13305.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# Extracting features from image -  13316.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# Extracting features from image -  13318.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# Extracting features from image -  13321.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# Extracting features from image -  13325.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# Extracting features from image -  13326.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# Extracting features from image -  13329.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# Extracting features from image -  13330.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step
# Extracting features from image -  150.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# Extracting features from image -  151.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# Extracting features from image -  152.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# Extracting features from image -  153.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# Extracting features from image -  154.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# Extracting features from image -  155.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# Extracting features from image -  156.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# Extracting features from image -  157.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step
# Extracting features from image -  158.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# Extracting features from image -  159.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step
# Extracting features from image -  160.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# Extracting features from image -  161.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# Extracting features from image -  162.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# Extracting features from image -  163.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step
# Extracting features from image -  164.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# Extracting features from image -  165.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# Extracting features from image -  166.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# Extracting features from image -  167.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# Extracting features from image -  168.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# Extracting features from image -  169.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# Extracting features from image -  170.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# Extracting features from image -  171.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step
# Extracting features from image -  172.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step
# Extracting features from image -  173.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# Extracting features from image -  174.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step
# Extracting features from image -  175.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# Extracting features from image -  176.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# Extracting features from image -  177.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step
# Extracting features from image -  178.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# Extracting features from image -  179.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# Extracting features from image -  180.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# Extracting features from image -  181.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# Extracting features from image -  182.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# Extracting features from image -  184.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step
# Extracting features from image -  185.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# Extracting features from image -  186.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# Extracting features from image -  187.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step
# Extracting features from image -  188.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# Extracting features from image -  189.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# Extracting features from image -  190.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# Extracting features from image -  191.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# Extracting features from image -  192.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# Extracting features from image -  193.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step
# Extracting features from image -  194.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# Extracting features from image -  195.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step
# Extracting features from image -  196.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# Extracting features from image -  197.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step
# Extracting features from image -  198.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# Extracting features from image -  199.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# Extracting features from image -  2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# Extracting features from image -  200.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step
# Extracting features from image -  20062.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# Extracting features from image -  20082.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# Extracting features from image -  20089.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step
# Extracting features from image -  20091.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# Extracting features from image -  20095.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# Extracting features from image -  20098.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# Extracting features from image -  201.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# Extracting features from image -  20100.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# Extracting features from image -  20108.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# Extracting features from image -  20117.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step
# Extracting features from image -  20134.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# Extracting features from image -  20136.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step
# Extracting features from image -  20138.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# Extracting features from image -  20147.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# Extracting features from image -  20148.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# Extracting features from image -  20150.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# Extracting features from image -  20151.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# Extracting features from image -  20159.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# Extracting features from image -  20165.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# Extracting features from image -  20166.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step
# Extracting features from image -  20167.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# Extracting features from image -  20168.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# Extracting features from image -  20170.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step
# Extracting features from image -  20171.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# Extracting features from image -  20172.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# Extracting features from image -  20173.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# Extracting features from image -  20175.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step
# Extracting features from image -  20185.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step
# Extracting features from image -  20190.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step
# Extracting features from image -  202.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step
# Extracting features from image -  20212.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step
# Extracting features from image -  20225.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# Extracting features from image -  20229.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# Extracting features from image -  20236.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# Extracting features from image -  20240.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# Extracting features from image -  20242.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step
# Extracting features from image -  20247.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# Extracting features from image -  20252.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# Extracting features from image -  203.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# Extracting features from image -  204.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step
# Extracting features from image -  20480.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step
# Extracting features from image -  20485.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step
# Extracting features from image -  20486.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step
# Extracting features from image -  20487.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# Extracting features from image -  20489.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step
# Extracting features from image -  20490.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# Extracting features from image -  20491.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# Extracting features from image -  20493.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# Extracting features from image -  20494.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step
# Extracting features from image -  20495.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# Extracting features from image -  20498.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# Extracting features from image -  205.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step
# Extracting features from image -  20502.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step
# Extracting features from image -  20508.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# Extracting features from image -  20510.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step
# Extracting features from image -  20511.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# Extracting features from image -  20513.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# Extracting features from image -  20516.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# Extracting features from image -  20517.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# Extracting features from image -  20519.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step
# Extracting features from image -  20520.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# Extracting features from image -  20527.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
# Extracting features from image -  20530.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# Extracting features from image -  20531.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step
# Extracting features from image -  20533.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# Extracting features from image -  20534.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# Extracting features from image -  20535.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# Extracting features from image -  20537.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step
# Extracting features from image -  20539.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# Extracting features from image -  20540.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# Extracting features from image -  20541.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step
# Extracting features from image -  20598.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# Extracting features from image -  206.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step
# Extracting features from image -  20602.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# Extracting features from image -  20603.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# Extracting features from image -  20605.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# Extracting features from image -  20615.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step
# Extracting features from image -  20616.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# Extracting features from image -  20619.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# Extracting features from image -  20620.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
# Extracting features from image -  20621.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# Extracting features from image -  20622.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# Extracting features from image -  20624.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step
# Extracting features from image -  20631.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# Extracting features from image -  20633.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step
# Extracting features from image -  20634.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# Extracting features from image -  20638.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# Extracting features from image -  20639.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# Extracting features from image -  20640.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step
# Extracting features from image -  20642.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# Extracting features from image -  20644.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# Extracting features from image -  20647.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# Extracting features from image -  20649.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step
# Extracting features from image -  20650.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# Extracting features from image -  20652.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step
# Extracting features from image -  20653.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step
# Extracting features from image -  20658.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# Extracting features from image -  20660.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# Extracting features from image -  20664.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# Extracting features from image -  20665.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step
# Extracting features from image -  20668.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step
# Extracting features from image -  20670.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step
# Extracting features from image -  20695.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step
# Extracting features from image -  207.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# Extracting features from image -  208.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# Extracting features from image -  20810.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step
# Extracting features from image -  20811.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# Extracting features from image -  20812.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# Extracting features from image -  20813.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# Extracting features from image -  20815.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# Extracting features from image -  20816.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step
# Extracting features from image -  20818.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step
# Extracting features from image -  20819.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# Extracting features from image -  20821.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# Extracting features from image -  20822.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step
# Extracting features from image -  209.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# Extracting features from image -  20907.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step
# Extracting features from image -  20909.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# Extracting features from image -  20910.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# Extracting features from image -  20911.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# Extracting features from image -  20915.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# Extracting features from image -  20916.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step
# Extracting features from image -  20917.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step
# Extracting features from image -  20921.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step
# Extracting features from image -  20924.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# Extracting features from image -  20925.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# Extracting features from image -  20927.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step
# Extracting features from image -  20929.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step
# Extracting features from image -  20930.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# Extracting features from image -  20931.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# Extracting features from image -  20933.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# Extracting features from image -  20934.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step
# Extracting features from image -  20935.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# Extracting features from image -  20937.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step
# Extracting features from image -  20938.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# Extracting features from image -  20942.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# Extracting features from image -  20944.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# ...
# Extracting features from image -  bike_176.bmp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# Extracting features from image -  bike_200.bmp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# Extracting features from image -  book.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# Extracting features from image -  bookedDetails.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# Extracting features from image -  bookpackage.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# Extracting features from image -  carsgraz_151.bmp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# Extracting features from image -  carsgraz_152.bmp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# Extracting features from image -  carsgraz_157.bmp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step
# Extracting features from image -  carsgraz_158.bmp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# Extracting features from image -  carsgraz_159.bmp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# Extracting features from image -  carsgraz_160.bmp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# Extracting features from image -  carsgraz_161.bmp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# Extracting features from image -  carsgraz_162.bmp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# Extracting features from image -  cat.14.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step
# Extracting features from image -  cat.15.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
# Extracting features from image -  cat.16.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# Extracting features from image -  cat.17.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step
# Extracting features from image -  cat.18.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# Extracting features from image -  cat.25.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# Extracting features from image -  cat.26.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step
# Extracting features from image -  cat.29.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# Extracting features from image -  cat.30.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
# Extracting features from image -  cat.31.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# Extracting features from image -  cat.32.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# Extracting features from image -  cat.33.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# Extracting features from image -  cat.34.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# Extracting features from image -  cat.35.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# Extracting features from image -  cat.43.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step
# Extracting features from image -  cat.44.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# Extracting features from image -  cat.45.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# Extracting features from image -  cat.46.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# Extracting features from image -  cat.47.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# Extracting features from image -  cat.48.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step
# Extracting features from image -  cat.49.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# Extracting features from image -  cat.50.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step
# Extracting features from image -  cat.6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# Extracting features from image -  chihuahua.JPG
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# Extracting features from image -  delete.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# Extracting features from image -  dest1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# Extracting features from image -  dest10.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# Extracting features from image -  dest2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# Extracting features from image -  dest3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# Extracting features from image -  dest4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
# Extracting features from image -  dest5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# Extracting features from image -  dest6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# Extracting features from image -  dest7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# Extracting features from image -  dest8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# Extracting features from image -  dest9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# Extracting features from image -  dog.1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# Extracting features from image -  dog.10.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# Extracting features from image -  dog.11.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step
# Extracting features from image -  dog.12.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# Extracting features from image -  dog.13.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step
# Extracting features from image -  dog.2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# Extracting features from image -  dog.3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# Extracting features from image -  dog.4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step
# Extracting features from image -  dog.5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step
# Extracting features from image -  dog.6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
# Extracting features from image -  dog.7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# Extracting features from image -  dog.8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# Extracting features from image -  dog.9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# Extracting features from image -  horse-100.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step
# Extracting features from image -  horse-101.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step
# Extracting features from image -  horse-102.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# Extracting features from image -  horse-103.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# Extracting features from image -  horse-104.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# Extracting features from image -  horse-105.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# Extracting features from image -  horse-61.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step
# Extracting features from image -  horse-62.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# Extracting features from image -  horse-63.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# Extracting features from image -  horse-64.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step
# Extracting features from image -  horse-65.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step
# Extracting features from image -  horse-66.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# Extracting features from image -  horse-82.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# Extracting features from image -  horse-83.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# Extracting features from image -  horse-84.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# Extracting features from image -  horse-85.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# Extracting features from image -  horse-86.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# Extracting features from image -  horse-87.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step
# Extracting features from image -  horse-88.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step
# Extracting features from image -  horse-89.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# Extracting features from image -  horse-90.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# Extracting features from image -  horse-97.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# Extracting features from image -  horse-98.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step
# Extracting features from image -  horse-99.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step
# Extracting features from image -  hotel1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# Extracting features from image -  hotel10.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# Extracting features from image -  hotel2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# Extracting features from image -  hotel3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# Extracting features from image -  hotel4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# Extracting features from image -  hotel5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# Extracting features from image -  hotel6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# Extracting features from image -  hotel7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# Extracting features from image -  hotel8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# Extracting features from image -  hotel9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# Extracting features from image -  irish_terrier.JPG
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# Extracting features from image -  monkey1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# Extracting features from image -  monkey2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# Extracting features from image -  newcustomer.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# Extracting features from image -  package1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# Extracting features from image -  package2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# Extracting features from image -  package3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# Extracting features from image -  rider-1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# Extracting features from image -  rider-10.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# Extracting features from image -  rider-11.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# Extracting features from image -  rider-12.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# Extracting features from image -  rider-13.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# Extracting features from image -  rider-14.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# Extracting features from image -  rider-15.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# Extracting features from image -  rider-151.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# Extracting features from image -  rider-152.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step
# Extracting features from image -  rider-153.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step
# Extracting features from image -  rider-154.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# Extracting features from image -  rider-155.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# Extracting features from image -  rider-156.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# Extracting features from image -  rider-16.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# Extracting features from image -  rider-17.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step
# Extracting features from image -  rider-18.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# Extracting features from image -  rider-19.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# Extracting features from image -  rider-2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# Extracting features from image -  rider-20.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step
# Extracting features from image -  rider-21.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step
# Extracting features from image -  rider-22.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step
# Extracting features from image -  rider-23.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# Extracting features from image -  rider-24.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step
# Extracting features from image -  rider-25.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# Extracting features from image -  rider-26.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# Extracting features from image -  rider-27.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step
# Extracting features from image -  rider-28.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# Extracting features from image -  rider-29.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# Extracting features from image -  rider-3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step
# Extracting features from image -  rider-30.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# Extracting features from image -  rider-31.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step
# Extracting features from image -  rider-32.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step
# Extracting features from image -  rider-33.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step
# Extracting features from image -  rider-34.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# Extracting features from image -  rider-35.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# Extracting features from image -  rider-36.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step
# Extracting features from image -  rider-37.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step
# Extracting features from image -  rider-38.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# Extracting features from image -  rider-39.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# Extracting features from image -  rider-4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# Extracting features from image -  rider-40.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# Extracting features from image -  rider-41.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# Extracting features from image -  rider-42.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# Extracting features from image -  rider-43.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# Extracting features from image -  rider-44.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# Extracting features from image -  rider-45.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# Extracting features from image -  rider-46.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# Extracting features from image -  rider-47.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# Extracting features from image -  rider-48.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# Extracting features from image -  rider-49.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# Extracting features from image -  rider-5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step
# Extracting features from image -  rider-50.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# Extracting features from image -  rider-51.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# Extracting features from image -  rider-52.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# Extracting features from image -  rider-53.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# Extracting features from image -  rider-54.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# Extracting features from image -  rider-55.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# Extracting features from image -  rider-56.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# Extracting features from image -  rider-57.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step
# Extracting features from image -  rider-58.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
# Extracting features from image -  rider-59.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# Extracting features from image -  rider-60.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# Extracting features from image -  rider-61.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step
# Extracting features from image -  rider-62.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step
# Extracting features from image -  rider-63.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step
# Extracting features from image -  rider-64.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step
# Extracting features from image -  rider-65.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# Extracting features from image -  rider-66.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# Extracting features from image -  rider-67.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# Extracting features from image -  rider-68.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# Extracting features from image -  rider-69.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step
# Extracting features from image -  rider-7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step
# Extracting features from image -  rider-70.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step
# Extracting features from image -  rider-71.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# Extracting features from image -  rider-72.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# Extracting features from image -  rider-73.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# Extracting features from image -  rider-74.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step
# Extracting features from image -  rider-8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step
# Extracting features from image -  rider-9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step
# Extracting features from image -  splash.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# Extracting features from image -  tiger1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# Extracting features from image -  tiger2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# Extracting features from image -  update.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# Extracting features from image -  zebra1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# Extracting features from image -  zebra2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #ffeacc; font-size:130%; text-align:left">
# Vectorize Text Features and Combine with Image Features

# %%
# Vectorize the extracted text using TF-IDF
vectorizer = TfidfVectorizer()
text_features = vectorizer.fit_transform(texts).toarray()

# Save the vectorizer
with open("vectorizer.pkl", "wb") as f:
    pickle.dump(vectorizer, f)

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #ffeacc; font-size:130%; text-align:left">
# Save Combined Features to HDF5 File

# %%
# Ensure text_features have the same number of rows as feats
if text_features.shape[0] != feats.shape[0]:
    print("Mismatch between image features and text features dimensions.")
else:
    # Combine the VGG-16 image features and text features
    combined_features = np.hstack((feats, text_features))

    # Directory for storing extracted features
    output = "CombinedFeatures.h5"

    # Write the combined features to an HDF5 file
    print("Writing feature extraction results to h5 file")
    h5f = h5py.File(output, 'w')
    h5f.create_dataset('dataset_1', data=combined_features)
    h5f.create_dataset('dataset_2', data=np.string_(names))
    h5f.close()
# Out:
# Writing feature extraction results to h5 file
